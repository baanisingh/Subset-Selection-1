# %% [markdown]
# <a href="https://colab.research.google.com/github/baanisingh/Subset-Selection-1/blob/main/Subset_Selection_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Subset Selection Problem**

# %% [markdown]
# 1. **Problem Statement:**
# Find all the subsets from a set of numbers whose sum is zero.
#
# **Constraint:**
# **Subset size must be 5**
#
# Set={-12, -3, -6, 7, 2, -2, 6, 3, 9, -7, -5, -8, 1, 11, -9, -4}

# %%
#We are importing the libraries and setting the parameters
import random as r

Set=set([-12, -3, -6, 7, 2, -2, 6, 3, 9, -7, -5, -8, 1, 11, -9, -4])
SetSize=5
Result=set()
iterations=2000

#This is the start of the program
for i in range(iterations):
  nums=r.sample(Set,SetSize)
  nums.sort()
  if(sum(nums)==0):
    Result.add(tuple(nums))

for r in Result:
  print(r)
print("\nTotal Sets: ",len(Result))
# Out:
# (-12, -3, 2, 6, 7)
# (-12, -6, 2, 7, 9)
# (-12, -6, 3, 6, 9)
# (-9, -3, 2, 3, 7)
# (-12, -9, 1, 9, 11)
# (-6, -5, 1, 3, 7)
# (-7, -4, -3, 3, 11)
# (-5, -4, -3, 1, 11)
# (-7, -4, 2, 3, 6)
# (-12, -2, 1, 6, 7)
# (-9, -5, 1, 2, 11)
# (-7, -3, 1, 3, 6)
# (-9, -7, 2, 3, 11)
# (-9, -7, -4, 9, 11)
# (-7, -4, 1, 3, 7)
# (-9, -2, 2, 3, 6)
# (-6, -4, 1, 2, 7)
# (-12, -3, 1, 3, 11)
# (-8, -7, 1, 3, 11)
# (-12, -7, 2, 6, 11)
# (-6, -5, -3, 3, 11)
# (-7, -3, 1, 2, 7)
# (-8, -5, -2, 6, 9)
# (-12, -2, 2, 3, 9)
# (-6, -3, 1, 2, 6)
# (-8, -4, 1, 2, 9)
# (-9, -8, 1, 7, 9)
# (-6, -4, -2, 3, 9)
# (-9, -7, 3, 6, 7)
# (-8, -5, -3, 7, 9)
# (-8, -5, 1, 3, 9)
# (-7, -5, 1, 2, 9)
# (-6, -5, -4, 6, 9)
# (-9, -7, 1, 6, 9)
# (-9, -5, -3, 6, 11)
# (-7, -3, -2, 1, 11)
# (-9, -6, 1, 3, 11)
# (-8, -3, 2, 3, 6)
# (-5, -4, -3, 3, 9)
# (-9, -6, 2, 6, 7)
# (-6, -4, -2, 1, 11)
# (-12, -7, 1, 7, 11)
# (-7, -6, -4, 6, 11)
# (-12, -8, 2, 7, 11)
# (-6, -5, -2, 6, 7)
# (-9, -3, -2, 3, 11)
# (-9, -4, 1, 3, 9)
# ...
